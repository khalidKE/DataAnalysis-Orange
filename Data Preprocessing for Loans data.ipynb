# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loans.csv')

# %%
df.head()
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id  loan_start    loan_end  \
# 0      46109      home        13672       0    10243  2002-04-16  2003-12-20
# 1      46109    credit         9794       0    10984  2003-10-21  2005-07-17
# 2      46109      home        12734       1    10990  2006-02-01  2007-07-05
# 3      46109      cash        12518       1    10596  2010-12-08  2013-05-05
# 4      46109    credit        14049       1    11415  2010-07-07  2012-05-21
#
#    rate
# 0  2.15
# 1  1.25
# 2  0.68
# 3  1.24
# 4  3.13

# %%
df.shape
# Out:
# (443, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   client_id    443 non-null    int64
#  1   loan_type    443 non-null    object
#  2   loan_amount  443 non-null    int64
#  3   repaid       443 non-null    int64
#  4   loan_id      443 non-null    int64
#  5   loan_start   443 non-null    object
#  6   loan_end     443 non-null    object
#  7   rate         443 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 27.8+ KB

# %%
high_loan= df[df['loan_amount']> df['loan_amount'].mean()]

high_loan.head()
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id  loan_start    loan_end  \
# 0      46109      home        13672       0    10243  2002-04-16  2003-12-20
# 1      46109    credit         9794       0    10984  2003-10-21  2005-07-17
# 2      46109      home        12734       1    10990  2006-02-01  2007-07-05
# 3      46109      cash        12518       1    10596  2010-12-08  2013-05-05
# 4      46109    credit        14049       1    11415  2010-07-07  2012-05-21
#
#    rate
# 0  2.15
# 1  1.25
# 2  0.68
# 3  1.24
# 4  3.13

# %%
df.dtypes
# Out:
# client_id        int64
# loan_type       object
# loan_amount      int64
# repaid           int64
# loan_id          int64
# loan_start      object
# loan_end        object
# rate           float64
# dtype: object

# %%
df['loan_id']=df['loan_id'].astype('object')

df['repaid']=df['repaid'].astype('category')

# %%
df['loan_start']=pd.to_datetime(df['loan_start'],format='%Y-%m-%d')


df['loan_end']=pd.to_datetime(df['loan_end'],format='%Y-%m-%d')


df.head()
# Out:
#    client_id loan_type  loan_amount repaid loan_id loan_start   loan_end  rate
# 0      46109      home        13672      0   10243 2002-04-16 2003-12-20  2.15
# 1      46109    credit         9794      0   10984 2003-10-21 2005-07-17  1.25
# 2      46109      home        12734      1   10990 2006-02-01 2007-07-05  0.68
# 3      46109      cash        12518      1   10596 2010-12-08 2013-05-05  1.24
# 4      46109    credit        14049      1   11415 2010-07-07 2012-05-21  3.13

# %%
df.dtypes
# Out:
# client_id               int64
# loan_type              object
# loan_amount             int64
# repaid               category
# loan_id                object
# loan_start     datetime64[ns]
# loan_end       datetime64[ns]
# rate                  float64
# dtype: object

# %%
summary_stats = df.describe()
print(summary_stats)

categorical_summary = df.describe(include='object')
print(categorical_summary)
# Out:
#           client_id   loan_amount                     loan_start  \
# count    443.000000    443.000000                            443
# mean   38911.060948   7982.311512  2007-08-02 12:56:53.092550912
# min    25707.000000    559.000000            2000-01-26 00:00:00
# 25%    32885.000000   4232.500000            2003-10-19 00:00:00
# 50%    39505.000000   8320.000000            2007-03-10 00:00:00
# 75%    46109.000000  11739.000000            2011-07-31 00:00:00
# max    49624.000000  14971.000000            2014-11-11 00:00:00
# std     7768.681063   4172.891992                            NaN
#
#                             loan_end        rate
# count                            443  443.000000
# mean   2009-08-23 11:35:37.246049536    3.217156
# min              2001-08-02 00:00:00    0.010000
# 25%              2005-09-12 12:00:00    1.220000
# 50%              2009-03-19 00:00:00    2.780000
# 75%              2013-09-11 12:00:00    4.750000
# max              2017-05-07 00:00:00   12.620000
# std                              NaN    2.397168
#        loan_type  loan_id
# count        443      443
# unique         4      443
# top         home    10243
# freq         121        1

# %%
df.isnull().sum()
# Out:
# client_id      0
# loan_type      0
# loan_amount    0
# repaid         0
# loan_id        0
# loan_start     0
# loan_end       0
# rate           0
# dtype: int64

# %%
high_loans = df[df['loan_amount'] > df['loan_amount'].mean()]
print(high_loans.head())
# Out:
#    client_id loan_type  loan_amount repaid loan_id loan_start   loan_end  rate
# 0      46109      home        13672      0   10243 2002-04-16 2003-12-20  2.15
# 1      46109    credit         9794      0   10984 2003-10-21 2005-07-17  1.25
# 2      46109      home        12734      1   10990 2006-02-01 2007-07-05  0.68
# 3      46109      cash        12518      1   10596 2010-12-08 2013-05-05  1.24
# 4      46109    credit        14049      1   11415 2010-07-07 2012-05-21  3.13

# %%
loan_by_type = df.groupby('loan_type')['loan_amount'].mean()
print(loan_by_type)
# Out:
# loan_type
# cash      8098.000000
# credit    7429.084112
# home      8009.347107
# other     8388.196262
# Name: loan_amount, dtype: float64

# %%
df['loan_amount'].plot(kind='box')
plt.show()

# %%
df['rate'].plot(kind='box')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#              client_id  loan_amount      rate
# client_id     1.000000     0.046507  0.058672
# loan_amount   0.046507     1.000000 -0.033340
# rate          0.058672    -0.033340  1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['loan_amount'], bins=30)
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Loan Amount')
plt.show()

# %%
# %pip install ydata-profiling
# %pip install ipywidgets
from ydata_profiling import ProfileReport
from ydata_profiling.config import Settings

config = Settings()
config.plot.image_format = 'png'

profile = ProfileReport(df, title="Loan Data Report", config=config)
profile.to_file("loan_data_report.html")
profile
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ydata-profiling in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (4.18.1)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in c:\users\khaled\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# 100%|██████████| 8/8 [00:00<00:00, 114.08it/s]0<00:00, 18.44it/s, Describe variable: rate]
# Summarize dataset: 100%|██████████| 33/33 [00:40<00:00,  1.22s/it, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:25<00:00, 25.40s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00,  4.67it/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:548, in ProfileReport._repr_html_(self)
#     546 def _repr_html_(self) -> None:
#     547     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 548     self.to_notebook_iframe()
#
# File c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:521, in ProfileReport.to_notebook_iframe(self)
#     510 """Used to output the HTML representation to a Jupyter notebook.
#     511 When config.notebook.iframe.attribute is "src", this function creates a temporary HTML file
#     512 in `./tmp/profile_[hash].html` and returns an Iframe pointing to that contents.
#    (...)    517     This constructions solves problems with conflicting stylesheets and navigation links.
#     518 """
#     519 from IPython.display import display
# --> 521 from ydata_profiling.report.presentation.flavours.widget.notebook import (
#     522     get_notebook_iframe,
#     523 )
#     525 # Ignore warning: https://github.com/ipython/ipython/pull/11350/files
#     526 with warnings.catch_warnings():
#
# File c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\__init__.py:1
# ----> 1 from ydata_profiling.report.presentation.flavours.widget.alerts import WidgetAlerts
#       2 from ydata_profiling.report.presentation.flavours.widget.collapse import WidgetCollapse
#       3 from ydata_profiling.report.presentation.flavours.widget.container import (
#       4     WidgetContainer,
#       5 )
#
# File c:\Users\khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\alerts.py:3
#       1 from typing import List
# ----> 3 from ipywidgets import HTML, Button, widgets
#       5 from ydata_profiling.report.presentation.core import Alerts
#       6 from ydata_profiling.report.presentation.flavours.html import templates
#
# ModuleNotFoundError: No module named 'ipywidgets'
